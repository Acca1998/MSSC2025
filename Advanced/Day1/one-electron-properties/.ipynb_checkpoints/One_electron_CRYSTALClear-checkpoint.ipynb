# %% [markdown]
# # Electronic Properties

# %% [markdown]
# The computation of electronic properties is a key tool to characterize crystalline materials to describe those properties dependent on the behavior of electrons within the crystalline structure. In <span style="font-variant: small-caps;">Crystal</span> plenty of tools are available to evaluate and describe [one electron properties](https://tutorials.crystalsolutions.eu/tutorial.html?td=properties&tf=properties_tut).
#
# In this tutorial we will introduce some of the tools available in CRYSTALClear to plot and study the electronic structure of materials:
# * **Band Structure**
# * **Density of States**
#
# First, though, a few preliminary steps are required.

# %%
# !pip install crystalclear
# Out:
# Requirement already satisfied: crystalclear in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (0.2.4)
# Requirement already satisfied: pymatgen in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from crystalclear) (2024.10.3)
# Requirement already satisfied: mendeleev in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from crystalclear) (0.20.0)
# Requirement already satisfied: ase in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from crystalclear) (3.24.0)
# Requirement already satisfied: numpy>=1.19.5 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from ase->crystalclear) (2.2.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from ase->crystalclear) (1.14.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from ase->crystalclear) (3.10.0)
# Requirement already satisfied: Pygments<3.0.0,>=2.11.2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (2.19.1)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (2.0.36)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (0.4.6)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (1.2.15)
# Requirement already satisfied: pandas<3.0,>=2.1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (2.10.4)
# Requirement already satisfied: pyfiglet<0.9,>=0.8.post1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from mendeleev->crystalclear) (0.8.post1)
# Requirement already satisfied: joblib>=1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (1.4.2)
# Requirement already satisfied: monty>=2024.7.29 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (2024.12.10)
# Requirement already satisfied: networkx>=2.2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (3.4.2)
# Requirement already satisfied: palettable>=3.3.3 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (3.3.3)
# Requirement already satisfied: plotly>=4.5.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (5.24.1)
# Requirement already satisfied: pybtex>=0.24.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (0.24.0)
# Requirement already satisfied: requests>=2.32 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (2.32.3)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (0.18.7)
# Requirement already satisfied: spglib>=2.5.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (2.5.0)
# Requirement already satisfied: sympy>=1.2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (1.13.3)
# Requirement already satisfied: tabulate>=0.9 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pymatgen->crystalclear) (3.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from deprecated<2.0.0,>=1.2.14->mendeleev->crystalclear) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from matplotlib>=3.3.4->ase->crystalclear) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pandas<3.0,>=2.1->mendeleev->crystalclear) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pandas<3.0,>=2.1->mendeleev->crystalclear) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from plotly>=4.5.0->pymatgen->crystalclear) (9.0.0)
# Requirement already satisfied: PyYAML>=3.01 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pybtex>=0.24.0->pymatgen->crystalclear) (6.0.2)
# Requirement already satisfied: latexcodec>=1.0.4 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pybtex>=0.24.0->pymatgen->crystalclear) (3.0.0)
# Requirement already satisfied: six in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pybtex>=0.24.0->pymatgen->crystalclear) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->crystalclear) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->crystalclear) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.2->mendeleev->crystalclear) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from requests>=2.32->pymatgen->crystalclear) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from requests>=2.32->pymatgen->crystalclear) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from requests>=2.32->pymatgen->crystalclear) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from requests>=2.32->pymatgen->crystalclear) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/fbodo/miniconda3/envs/develop/lib/python3.13/site-packages (from sympy>=1.2->pymatgen->crystalclear) (1.3.0)

# %%
from CRYSTALClear.crystal_io import Properties_output
import CRYSTALClear.plot as CCplt
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Band Structure

# %% [markdown]
# In CRYSTALClear it is possible to plot the band structure computed through a <span style="font-variant: small-caps;">Properties</span> calculations starting from the BAND.DAT or the .f25 generated as computation output. To do so we first need to generate the crystal object containing the necessary informations for the plot. For the purpose of this tutorial we will start from a BAND.DAT file, all of the following instruction, though, remain valid also for the .f25 file.

# %%
# Definition of the BAND.DAT file
band = 'mgo_band.BAND'

# Creation of the Crystal Object
band = Properties_output().read_electron_band(band)

# %% [markdown]
# To generate the band structure plot the only required argument is the Crystal Object generated above, some additional argument, though, might help with the plot readability:
# * *energy_range*: Will limit the range of energy displayed in the band structure plot
# * *k_labels*: Will specify the tick labels associated with the high symmetry point explored in the band structure calculation
#
# Given this premises we can proceed plotting the MgO band structure.

# %%
# Plotting function
CCplt.plot_electron_band(band, energy_range=[-10,15], linewidth=1.5, figsize=(6,6), k_labels=['Gamma','X','W','L','Gamma'])
plt.show()

# %% [markdown]
# From time to time it might come in handy to plot two different band structures of the same material to see how it changes under given conditions.

# %% [markdown]
# ### 2. Density of States (DOS)

# %% [markdown]
# ### 3. Electronic Structure
